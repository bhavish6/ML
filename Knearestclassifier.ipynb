# %%
import pandas as pd
import matplotlib.pyplot as plt
file = r'https://raw.githubusercontent.com/jigar-pandit/ml1/master/breast_cancer.csv'
df = pd.read_csv(file)
df.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
X = df.drop(columns = ['diagnosis'],axis=1)
X.head()
# Out:
#          id  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0    842302        17.99  ...          0.4601                  0.11890
# 1    842517        20.57  ...          0.2750                  0.08902
# 2  84300903        19.69  ...          0.3613                  0.08758
# 3  84348301        11.42  ...          0.6638                  0.17300
# 4  84358402        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
y = df['diagnosis'].values

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test ,y_train ,y_test = train_test_split(X , y , test_size=0.3 , stratify=y ,random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
KNeighborsClassifier(algorithm='auto',leaf_size=30,metric='minkowski',metric_params=None,n_jobs=None,n_neighbors=7,p=2,
                     weights='uniform')
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
knn.predict(X_test)
# Out:
# array(['B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M'], dtype=object)

# %%
plt.plot(neighbors_settings,training_accuracy,label="training accuracy")
plt.plot(neighbors_settings,test_accuracy,label="test accuracy")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3e3911786bdc> in <module>()
# ----> 1 plt.plot(neighbors_settings,training_accuracy,label="training accuracy")
#       2 plt.plot(neighbors_settings,test_accuracy,label="test accuracy")
#       3 plt.legend()
#
# NameError: name 'neighbors_settings' is not defined
